# %% [markdown]
# <a href="https://colab.research.google.com/github/yujeong-hub/AIFFEL_quest_cr/blob/main/Python/Quest02/250110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 텍스트 전처리를 수행한다.
# Avengers.txt 파일을 불러온다. o
# 모든 문자는 소문자로 변환한다. o
# 모든 기호를 제거한다. ㅇ
# 단어 단위로 분리한다. ㅇ
# 결과:
# "I am hungry..very much..." -> [ 'i', 'am', 'hungry', 'very', 'much']
# 2.  각 단어 별 빈도수를 딕셔너리 형태로 저장한다.ㅇ
# 3. 딕셔너리를 빈도수순으로 내림차순 정렬하고, 정렬 순서대로 정수 인덱스를 부여한다.
# 4. 텍스트를 input()으로 입력받아서 정수를 return하는 함수를 만든다.

file_path = '/Avengers.txt'  # 파일 경로 설정
with open(file_path, 'r') as file:
    content = file.read()

content = content.lower()
content = content.replace("," , "")
content = content.replace("." , "")
content = content.replace("'", "")
content = content.replace("-", "")
content = content.replace("?", "")

content=content.split(' ')

frequency_of_words = {}
for word in content:
  if word in frequency_of_words:
    frequency_of_words[word] += 1
  else:
    frequency_of_words[word] = 1


s_f=sorted(frequency_of_words.items(), key=lambda x:x[1], reverse=True)

word, number = zip(*s_f)

tuple_word=[]
for i in enumerate(word):
  tuple_word.append(i)

dictionary=dict(tuple_word)
print(dictionary)
# Out:
# {0: 'the', 1: 'you', 2: 'to', 3: 'a', 4: 'i', 5: 'of', 6: 'is', 7: 'that', 8: 'on', 9: 'in', 10: 'we', 11: 'not', 12: 'and', 13: 'it', 14: 'for', 15: 'have', 16: 'be', 17: 'this', 18: 'what', 19: 'he', 20: 'are', 21: 'know', 22: 'its', 23: 'was', 24: 'me', 25: 'get', 26: 'your', 27: 'dont', 28: 'my', 29: 'out', 30: 'do', 31: 'need', 32: 'like', 33: 'got', 34: 'no', 35: 'im', 36: 'all', 37: 'an', 38: 'will', 39: 'can', 40: 'with', 41: 'gonna', 42: 'his', 43: 'up', 44: 'they', 45: 'about', 46: 'did', 47: 'were', 48: 'think', 49: 'if', 50: 'just', 51: 'come', 52: 'from', 53: 'didnt', 54: 'well', 55: 'tesseract', 56: 'as', 57: 'how', 58: 'hes', 59: 'youre', 60: 'so', 61: 'but', 62: 'should', 63: 'them', 64: 'put', 65: 'loki', 66: 'has', 67: 'cant', 68: 'stark', 69: 'here', 70: 'thats', 71: 'our', 72: 'there', 73: 'one', 74: 'him', 75: 'world', 76: 'tell', 77: 'back', 78: 'right', 79: 'us', 80: 'at', 81: 'take', 82: 'fury', 83: 'why', 84: 'you\n', 85: 'down', 86: 'only', 87: 'off', 88: 'm
# ...
